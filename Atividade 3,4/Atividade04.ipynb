# %% [markdown]
# #** CENTRO DE TECNOLÓGIA DO AMAZONAS - IBC**
# ### Institutor Benjamim Constant
# ### Curso de nível Técnico de Inteligência Artificial*
# ### Manaus, 24 de Março de 2026 negrito
#
# ---
#
# # Aluna: Beatriz de Sousa Falcão

# %%
nu1 = 0
nu2 = 0
print('olá, mundo')
print (5+5-2)
print (nu1)
print (5**2)
print (nu2)
# Out:
# olá, mundo
# 8
# 0
# 25
# 0

# %%
# Script 1
# Função criada pelo usuário
def dobro(x):
    print(x * 2)

dobro(125)
# Out:
# 250

# %%
print("Curso Técnico em Nível de Inteligência Artificial - Turma 2026.1")
# Out:
# Curso Técnico em Nível de Inteligência Artificial - Turma 2026.1
