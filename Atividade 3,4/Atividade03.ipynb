# %% [markdown]
# # **CENTRO DE TECNOLÓGIA DO AMAZONAS - IBC**
# ## **Institutor Benjamim Constant**
#
# ### **Curso de nível Técnico de Inteligência Artificial***
# ### Manaus, 23 de Março de 2026
#
#
# ---
#
#
# # Aluna: Beatriz de Sousa Falcão

# %%
print("Olá, mundo")
# Out:
# Olá, mundo

# %%
2 + 3
# Out:
# 5

# %%
50 - 5 * 7
# Out:
# 15

# %%
(50 - 5*6) / 2
# Out:
# 10.0

# %%
print(int(8/5))         # divisão com operandos inteiros, retorna resultado inteiro (vs.2.7)
print(8./5)             # divisão com pelo menos um operando real, retorna resultado real (vs.2.7)
# Out:
# 1
# 1.6

# %%
5**2                     # 5 elevado ao quadrodo
# Out:
# 25

# %%
59 ** - 2
# Out:
# 0.0002872737719046251

# %%
numero = 59
resultado = bin (numero)
print(resultado) # Saída 111011
# Out:
# 0b111011

# %%
#Calculadora():
print("---Calculadora Python---")
print("Operações disponíveis:")
print("1: Adição(+)")
print("2: Subtração(-)")
print("3: Multiplicação(*)")
print("4: Divisão(/)")

try:
  operacao = input("\nEscolher o número da operação desejada (1/2/3/4):") # Read as string to compare with '1', '2', '3', '4'

  if operacao in ['1', '2', '3', '4']:
    num1 = float(input("Digite o primeiro número:"))
    num2 = float(input("Digite o segundo número:"))

    if operacao == '1':
      print(f"Resultado: {num1} + {num2} = {num1 + num2}")
    elif operacao == '2':
      print(f"Resultado: {num1} - {num2} = {num1 - num2}")
    elif operacao == '3':
      print(f"Resultado: {num1} * {num2} = {num1 * num2}")
    elif operacao == '4':
      # Check for division by zero
      if num2 == 0:
        print("Erro: Divisão por zero!")
      else:
        print(f"Resultado: {num1} / {num2} = {num1 / num2}")
  else:
    print("Opção inválida!")
except ValueError:
  print("Erro: Por favor, digite apenas números válidos!")
except Exception as e:
  print(f"Ocorreu um erro inesperado: {e}")
# Out:
# ---Calculadora Python---
# Operações disponíveis:
# 1: Adição(+)
# 2: Subtração(-)
# 3: Multiplicação(*)
# 4: Divisão(/)
#
# Escolher o número da operação desejada (1/2/3/4):1
# Digite o primeiro número:2
# Digite o segundo número:3
# Resultado: 2.0 + 3.0 = 5.0
