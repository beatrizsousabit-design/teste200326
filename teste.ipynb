# %% [markdown]
# <a href="https://colab.research.google.com/github/beatrizsousabit-design/teste200326/blob/main/teste.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time # *Biblioteca para simular o tempo passando*

# %%
print ("--- INICIANDO O ALGORITIMO DO BOLO ---")
# Out:
# --- INICIANDO O ALGORITIMO DO BOLO ---

# %%
# 1. Variáveis: Separando os ingredientes e ferrramentas
temperatura_forno = 0
forma_untada = True
tigela = [] # Uma lista vazia para colocar os ingredientes
massa_homogenea = False
tempo_forno = 40
palito_limpo = False

# %%
# 2. Entrada/Ações Simples
